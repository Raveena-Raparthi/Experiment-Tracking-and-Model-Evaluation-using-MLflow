# %%
import mlflow

# %%
#set a mlflow tracker

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("check the localhost server")
with mlflow.start_run():
    mlflow.log_param("param1",1)
    mlflow.log_metric("metric1",2)
